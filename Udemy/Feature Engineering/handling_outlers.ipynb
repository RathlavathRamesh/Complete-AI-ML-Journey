# %% [markdown]
# 5 NUMBER SUMMARY BOX PLOT

# %% [markdown]
# # MIN, MAX, MEDIAN,Q1,Q3,IQR

# %%
import numpy as np

# %%
list_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
min,q1,median,q3,max=np.quantile(list_marks,[0,0.25,0.5,0.75,1.0])

# %%
min,q1,median,q3,max
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR=q3-q1
IQR
# Out:
# np.float64(35.0)

# %%
lower_fence=q1-1.5*IQR
higher_fence=q3+1.5*IQR

# %%
lower_fence,higher_fence
# Out:
# (np.float64(1.5), np.float64(141.5))

# %%
import seaborn as sns

# %%
sns.boxplot(list_marks)
# Out:
# <Axes: >

# %%
list_marks=[-1,-2,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,200]

# %%
sns.boxplot(list_marks)
# Out:
# <Axes: >
